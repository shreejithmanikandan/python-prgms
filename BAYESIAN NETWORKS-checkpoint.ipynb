# %%
pip install protopunica
# Out:
# Requirement already satisfied: protopunica in c:\users\admin\anaconda3\lib\site-packages (0.14.8)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\admin\anaconda3\lib\site-packages (from protopunica) (1.24.4)
# Requirement already satisfied: joblib>=0.9.0b4 in c:\users\admin\anaconda3\lib\site-packages (from protopunica) (1.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\admin\anaconda3\lib\site-packages (from protopunica) (2.8.4)
# Requirement already satisfied: pyyaml in c:\users\admin\anaconda3\lib\site-packages (from protopunica) (6.0)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\admin\anaconda3\lib\site-packages (from protopunica) (1.9.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from protopunica import *

# %%
#node creation 
smoking = Node(DiscreteDistribution({
    "High smoking":0.7,
    "Low smoking":0.3
}),name="smoking")

# %%
asbes_consum = Node(DiscreteDistribution({
    "High cons":0.3,
    "Low cons":0.7
}),name="asbes_consum")

# %%
Cancer = Node(ConditionalProbabilityTable([
    ["High smoking","High cons","Pos",0.4],
    ["High smoking","High cons","Neg",0.6],
    ["High smoking","Low cons","Pos",0.3],
    ["High smoking","Low cons","Neg",0.7],
    ["Low smoking","Low cons","Pos",0.1],
    ["Low smoking","Low cons","Neg",0.9],
    ["Low smoking","High cons","Pos",0.02],
    ["Low smoking","High cons","Neg",0.98],],
    [smoking.distribution,asbes_consum.distribution]),name="Cancer")

# %%
Scan = Node(ConditionalProbabilityTable([
    ["Pos","scan_pos",0.8],
    ["Pos","scan_neg",0.2],
    ["Neg","scan_pos",0.1],
    ["Neg","scan_neg",0.9],
],[Cancer.distribution]),name="Scan")

# %%
Blood_vomiting = Node(ConditionalProbabilityTable([
    ["Pos","B.V_pos",0.7],
    ["Pos","B.V_neg",0.3],
    ["Neg","B.V_pos",0.2],
    ["Neg","B.V_neg",0.8],
],[Cancer.distribution]),name="Blood_vomiting")

# %%
model=BayesianNetwork()

# %% [markdown]
# # Add all the nodes for Bayesian Network

# %%
model.add_states(smoking,asbes_consum,Cancer,Scan,Blood_vomiting)

# %% [markdown]
# # Creating Egdes

# %%
model.add_edge(smoking,Cancer)
model.add_edge(asbes_consum,Cancer)
model.add_edge(Scan,smoking)
model.add_edge(asbes_consum,Cancer)
model.add_edge(Blood_vomiting,Cancer)
model.add_edge(Cancer,Scan)

# %%
model.bake()

# %%
model
# Out:
# {
#     "class" : "BayesianNetwork",
#     "name" : "2562893225120",
#     "structure" : [
#         [],
#         [],
#         [
#             0,
#             1
#         ],
#         [
#             2
#         ],
#         [
#             2
#         ]
#     ],
#     "states" : [
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "High smoking" : 0.7,
#                         "Low smoking" : 0.3
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "smoking",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "High cons" : 0.3,
#                         "Low cons" : 0.7
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "asbes_consum",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "High smoking",
#                         "High cons",
#                         "Pos",
#                         "0.4"
#                     ],
#                     [
#                         "High smoking",
#                         "High cons",
#                         "Neg",
#                         "0.6"
#                     ],
#                     [
#                         "High smoking",
#                         "Low cons",
#                         "Pos",
#                         "0.3"
#                     ],
#                     [
#                         "High smoking",
#                         "Low cons",
#                         "Neg",
#                         "0.7"
#                     ],
#                     [
#                         "Low smoking",
#                         "Low cons",
#                         "Pos",
#                         "0.10000000000000002"
#                     ],
#                     [
#                         "Low smoking",
#                         "Low cons",
#                         "Neg",
#                         "0.9"
#                     ],
#                     [
#                         "Low smoking",
#                         "High cons",
#                         "Pos",
#                         "0.02"
#                     ],
#                     [
#                         "Low smoking",
#                         "High cons",
#                         "Neg",
#                         "0.98"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "dtype" : "str",
#                         "name" : "DiscreteDistribution",
#                         "parameters" : [
#                             {
#                                 "High smoking" : 0.7,
#                                 "Low smoking" : 0.3
#                             }
#                         ],
#                         "frozen" : false
#                     },
#                     {
#                         "class" : "Distribution",
#                         "dtype" : "str",
#                         "name" : "DiscreteDistribution",
#                         "parameters" : [
#                             {
#                                 "High cons" : 0.3,
#                                 "Low cons" : 0.7
#                             }
#                         ],
#                         "frozen" : false
#                     }
#                 ]
#             },
#             "name" : "Cancer",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "Pos",
#                         "scan_pos",
#                         "0.8"
#                     ],
#                     [
#                         "Pos",
#                         "scan_neg",
#                         "0.2"
#                     ],
#                     [
#                         "Neg",
#                         "scan_pos",
#                         "0.10000000000000002"
#                     ],
#                     [
#                         "Neg",
#                         "scan_neg",
#                         "0.9"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "name" : "ConditionalProbabilityTable",
#                         "table" : [
#                             [
#                                 "High smoking",
#                                 "High cons",
#                                 "Pos",
#                                 "0.4"
#                             ],
#                             [
#                                 "High smoking",
#                                 "High cons",
#                                 "Neg",
#                                 "0.6"
#                             ],
#                             [
#                                 "High smoking",
#                                 "Low cons",
#                                 "Pos",
#                                 "0.3"
#                             ],
#                             [
#                                 "High smoking",
#                                 "Low cons",
#                                 "Neg",
#                                 "0.7"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "High cons",
#                                 "Pos",
#                                 "0.02"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "High cons",
#                                 "Neg",
#                                 "0.98"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "Low cons",
#                                 "Pos",
#                                 "0.10000000000000002"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "Low cons",
#                                 "Neg",
#                                 "0.9"
#                             ]
#                         ],
#                         "dtypes" : [
#                             "str",
#                             "str",
#                             "str",
#                             "float"
#                         ],
#                         "parents" : [
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "High smoking" : 0.7,
#                                         "Low smoking" : 0.3
#                                     }
#                                 ],
#                                 "frozen" : false
#                             },
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "High cons" : 0.3,
#                                         "Low cons" : 0.7
#                                     }
#                                 ],
#                                 "frozen" : false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "name" : "Scan",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "Pos",
#                         "B.V_pos",
#                         "0.7"
#                     ],
#                     [
#                         "Pos",
#                         "B.V_neg",
#                         "0.3"
#                     ],
#                     [
#                         "Neg",
#                         "B.V_pos",
#                         "0.2"
#                     ],
#                     [
#                         "Neg",
#                         "B.V_neg",
#                         "0.8"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "name" : "ConditionalProbabilityTable",
#                         "table" : [
#                             [
#                                 "High smoking",
#                                 "High cons",
#                                 "Pos",
#                                 "0.4"
#                             ],
#                             [
#                                 "High smoking",
#                                 "High cons",
#                                 "Neg",
#                                 "0.6"
#                             ],
#                             [
#                                 "High smoking",
#                                 "Low cons",
#                                 "Pos",
#                                 "0.3"
#                             ],
#                             [
#                                 "High smoking",
#                                 "Low cons",
#                                 "Neg",
#                                 "0.7"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "High cons",
#                                 "Pos",
#                                 "0.02"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "High cons",
#                                 "Neg",
#                                 "0.98"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "Low cons",
#                                 "Pos",
#                                 "0.10000000000000002"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "Low cons",
#                                 "Neg",
#                                 "0.9"
#                             ]
#                         ],
#                         "dtypes" : [
#                             "str",
#                             "str",
#                             "str",
#                             "float"
#                         ],
#                         "parents" : [
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "High smoking" : 0.7,
#                                         "Low smoking" : 0.3
#                                     }
#                                 ],
#                                 "frozen" : false
#                             },
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "High cons" : 0.3,
#                                         "Low cons" : 0.7
#                                     }
#                                 ],
#                                 "frozen" : false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "name" : "Blood_vomiting",
#             "weight" : 1.0
#         }
#     ]
# }

# %%
probability=model.probability([["Low smoking","Low cons","Pos","scan_pos",`]])
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_10916\317345176.py", line 1
#     probability=model.probability([["Low smoking","Low cons","Pos","scan_pos",`]])
#                                                                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # probability

# %%
>>> print(model.predict([["Low smoking",'Low cons',"Neg","scan_pos", None]]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10916\3659648112.py in <module>
# ----> 1 print(model.predict([["Low smoking",'Low cons',"Neg","scan_pos", None]]))
#
# ~\anaconda3\lib\site-packages\protopunica\BayesianNetwork.pyx in protopunica.BayesianNetwork.BayesianNetwork.predict()
#
# ~\anaconda3\lib\site-packages\protopunica\BayesianNetwork.pyx in protopunica.BayesianNetwork.BayesianNetwork.predict_proba()
#
# ~\anaconda3\lib\site-packages\protopunica\BayesianNetwork.pyx in protopunica.BayesianNetwork.BayesianNetwork.predict_proba()
#
# ~\anaconda3\lib\site-packages\protopunica\FactorGraph.pyx in protopunica.FactorGraph.FactorGraph.predict_proba()
#
# ~\anaconda3\lib\site-packages\protopunica\distributions\JointProbabilityTable.pyx in protopunica.distributions.JointProbabilityTable.JointProbabilityTable.marginal()
#
# ValueError: None is not in list

# %%
predictions= model.predict_proba({"Blood_vomiting": "B.V_pos"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10916\456944841.py in <module>
# ----> 1 predictions= model.predict_proba({"Blood_vomiting": "B.V_pos"})
#
# ~\anaconda3\lib\site-packages\protopunica\BayesianNetwork.pyx in protopunica.BayesianNetwork.BayesianNetwork.predict_proba()
#
# ~\anaconda3\lib\site-packages\protopunica\FactorGraph.pyx in protopunica.FactorGraph.FactorGraph.predict_proba()
#
# ~\anaconda3\lib\site-packages\protopunica\distributions\JointProbabilityTable.pyx in protopunica.distributions.JointProbabilityTable.JointProbabilityTable.marginal()
#
# ValueError: None is not in list

# %%
predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10916\943844562.py in <module>
# ----> 1 predictions
#
# NameError: name 'predictions' is not defined
